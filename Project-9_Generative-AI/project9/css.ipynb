# %%
/* static/styles.css */
body {
    font-family: Arial, sans-serif;
}

.chat-container {
    max-width: 500px;
    margin: 0 auto;
    padding: 20px;
    border: 1px solid #ccc;
    border-radius: 8px;
}

.chat-box {
    height: 200px;
    overflow-y: auto;
    padding: 10px;
    border: 1px solid #ccc;
    border-radius: 8px;
    background-color: #f5f5f5;
}

.chat-message {
    margin-bottom: 5px;
    padding: 5px;
    border-radius: 5px;
}

.bot {
    background-color: #d3ffd3;
}

.user-input {
    margin-top: 10px;
}

#user-input-box {
    width: 70%;
    padding: 5px;
    border: 1px solid #ccc;
    border-radius: 5px;
}

button {
    padding: 5px 10px;
    margin-left: 5px;
    border: none;
}
